# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_groq import ChatGroq
from langchain.chat_models import init_chat_model
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from dotenv import load_dotenv
import os
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14732\1169432451.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import WebBaseLoader
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
model = init_chat_model(
    "openai/gpt-oss-120b",
    model_provider = "groq"
)

# %%
prompt = PromptTemplate(
    template = 'Answer the following question \n {question} from the following text - \n {text}',
    input_variables = ['question', 'text']
)

# %%
parser = StrOutputParser()

# %%
url = 'https://docs.langchain.com/oss/python/deepagents/rag'
loader = WebBaseLoader(url)

# %%
#Install beautifulsoup4

docs = loader.load()

# %%
chain = prompt | model | parser

# %%
text = docs[0].page_content[:20000]

print(chain.invoke({
    "question": "What is topic discussed here?",
    "text": text
}))
# Out:
# The passage is describing **Retrieval‑Augmented Generation (RAG) using LangChain’s “Deep Agents”** – a guide that explains how to build a documentation‑question‑answering agent (indexing LangChain docs, storing embeddings in a vector store, retrieving relevant chunks, off‑loading them to a filesystem, and delegating analysis to sub‑agents). It covers RAG patterns, why retrieval matters, and step‑by‑step setup for a Deep Agent‑based RAG system.
